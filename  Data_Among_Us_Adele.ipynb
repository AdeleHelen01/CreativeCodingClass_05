# %%
import pandas as pd

# %%
# %pylab inline
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
#Using indexing with wireframes
#getting the wayfinding file 
path = 'Way_city.csv'
# read the csv file and convert to a pandas DataFrame, store the DataFrame in 
# variable complaints
Way= pd.read_csv(path)

# %%
Way
Way.head()
# Out:
#                    Timestamp What is your me? Where do you live?  \
# 0  2022/11/16 8:02:00 PM GMT              NaN    Elephant&Castle
# 1  2022/11/16 8:12:46 PM GMT              NaN            Chelsea
# 2  2022/11/16 9:57:49 PM GMT            Rocio             London
# 3  2022/11/17 9:54:48 AM GMT             Jana          Battersea
# 4  2022/11/17 9:55:01 AM GMT            Tilly       Muswell Hill
#
#   How long does it take you to commute to CTA Hogarth?  \
# 0                                        5 - 30 mins
# 1                                             30-1hr
# 2                                        5 - 30 mins
# 3                                             30-1hr
# 4                                             30-1hr
#
#   Do you use mobile apps for travel and navigation: wayfinding  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   In terms of independent travel in your city or town, please rate your daily navigational journey while using mobile apps.   \
# 0                                               Good
# 1                                               Good
# 2                                          Excellent
# 3                                               Good
# 4                                               Fair
#
#   What form(s) of transport do you take in getting around in your city?  \
# 0                                   All of the above
# 1                                   All of the above
# 2                                                Bus
# 3                                                Bus
# 4                                                Bus
#
#   Do you use public transport such as trains, bus, ferry, etc?  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   In getting to you desired location, and the Hogarth office what are your daily challenges?  \
# 0                            Catch the train on time
# 1  Dealing with the crowds during rush hour and s...
# 2    Bus is so busy it doesn't allow anyone to go in
# 3                                               Rain
# 4                                            traffic
#
#   Do you use different mobile apps to choose the best route to get to your destination?  \
# 0                                                 No
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
#
#   How many mobile apps do you use for your journey?  \
# 0                                               0-3
# 1                                               0-3
# 2                                               0-3
# 3                                               0-3
# 4                                               0-3
#
#   Please list the mobile app you use on a daily basis.  \
# 0                                         Google map
# 1   Citymapper, Google maps or Apple Maps if on foot
# 2                              Citimapper and Google
# 3                       Google Maps, Citymapper, TFL
# 4                                        google maps
#
#   Do the mobile aps fulfil your daily navigational needs for travel  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   Provide an example of how you think inclusion and accessibility can be enhanced through the use of daily mobile apps to adapt to daily movement, journey planning, and safety, creating a better user experience.
# 0                                       Combining AR
# 1  Important to note step free access, perhaps al...
# 2  Telling you if the bus that is coming is full ...
# 3                                                NaN
# 4  You should have the option to filter your rout...

# %%
# information of how many rows and columns 9-rows 14-columns
Way.shape
# Out:
# (9, 14)

# %%
#Getting the names of all my columms
Way.columns
# Out:
# Index(['Timestamp', 'What is your me?', 'Where do you live?',
#        'How long does it take you to commute to CTA Hogarth?',
#        'Do you use mobile apps for travel and navigation: wayfinding',
#        'In terms of independent travel in your city or town, please rate your daily navigational journey while using mobile apps. ',
#        'What form(s) of transport do you take in getting around in your city?',
#        'Do you use public transport such as trains, bus, ferry, etc?',
#        'In getting to you desired location, and the Hogarth office what are your daily challenges?',
#        'Do you use different mobile apps to choose the best route to get to your destination?',
#        'How many mobile apps do you use for your journey?',
#        'Please list the mobile app you use on a daily basis.',
#        'Do the mobile aps fulfil your daily navigational needs for travel',
#        'Provide an example of how you think inclusion and accessibility can be enhanced through the use of daily mobile apps to adapt to daily movement, journey planning, and safety, creating a better user experience.'],
#       dtype='object')

# %%
# shorten column names by using the rename function
Way = Way.rename(columns = {'Provide an example of how you think inclusion and accessibility can be enhanced through the use of daily mobile apps to adapt to daily movement, journey planning, and safety, creating a better user experience.':'Changes_needed','Do the mobile aps fulfil your daily navigational needs for travel':'Satisfactory_outcome','Please list the mobile app you use on a daily basis.':'Name_of_Apps','How many mobile apps do you use for your journey?': 'Total_Apps_Used','Do you use different mobile apps to choose the best route to get to your destination?':'Variation_mobile_apps','In getting to you desired location, and the Hogarth office what are your daily challenges?':'Travel_challenges','How long does it take you to commute to CTA Hogarth?':'Travel_Time','What form(s) of transport do you take in getting around in your city?':'Type_Transport','Do you use public transport such as trains, bus, ferry, etc?':'UsePublicTransport','Do you use mobile apps for travel and navigation: wayfinding':'Use_App_Travel','In terms of independent travel in your city or town, please rate your daily navigational journey while using mobile apps. ':'Rate_App',"What is your me?":'Name',"Where do you live?":'Area_Residence',"Do you use mobile apps for travel and navigation wayfinding?":'Use_App_for_Travel'})
Way.head()
# Out:
#                    Timestamp   Name   Area_Residence  Travel_Time  \
# 0  2022/11/16 8:02:00 PM GMT    NaN  Elephant&Castle  5 - 30 mins
# 1  2022/11/16 8:12:46 PM GMT    NaN          Chelsea       30-1hr
# 2  2022/11/16 9:57:49 PM GMT  Rocio           London  5 - 30 mins
# 3  2022/11/17 9:54:48 AM GMT   Jana        Battersea       30-1hr
# 4  2022/11/17 9:55:01 AM GMT  Tilly     Muswell Hill       30-1hr
#
#   Use_App_Travel   Rate_App    Type_Transport UsePublicTransport  \
# 0            Yes       Good  All of the above                Yes
# 1            Yes       Good  All of the above                Yes
# 2            Yes  Excellent               Bus                Yes
# 3            Yes       Good               Bus                Yes
# 4            Yes       Fair               Bus                Yes
#
#                                    Travel_challenges Variation_mobile_apps  \
# 0                            Catch the train on time                    No
# 1  Dealing with the crowds during rush hour and s...                   Yes
# 2    Bus is so busy it doesn't allow anyone to go in                   Yes
# 3                                               Rain                   Yes
# 4                                            traffic                    No
#
#   Total_Apps_Used                                      Name_of_Apps  \
# 0             0-3                                        Google map
# 1             0-3  Citymapper, Google maps or Apple Maps if on foot
# 2             0-3                             Citimapper and Google
# 3             0-3                      Google Maps, Citymapper, TFL
# 4             0-3                                       google maps
#
#   Satisfactory_outcome                                     Changes_needed
# 0                  Yes                                       Combining AR
# 1                  Yes  Important to note step free access, perhaps al...
# 2                  Yes  Telling you if the bus that is coming is full ...
# 3                  Yes                                                NaN
# 4                  Yes  You should have the option to filter your rout...

# %%
print('Number of Rows: ' + str(len(Way)))
# Out:
# Number of Rows: 9

# %%
Way.head(10)
# Out:
#                     Timestamp      Name   Area_Residence  Travel_Time  \
# 0   2022/11/16 8:02:00 PM GMT       NaN  Elephant&Castle  5 - 30 mins
# 1   2022/11/16 8:12:46 PM GMT       NaN          Chelsea       30-1hr
# 2   2022/11/16 9:57:49 PM GMT     Rocio           London  5 - 30 mins
# 3   2022/11/17 9:54:48 AM GMT      Jana        Battersea       30-1hr
# 4   2022/11/17 9:55:01 AM GMT     Tilly     Muswell Hill       30-1hr
# 5   2022/11/17 3:03:59 PM GMT       kat        Islington  5 - 30 mins
# 6  2022/11/18 12:23:08 PM GMT      Dara            Essex      1-2 hrs
# 7   2022/11/18 1:19:35 PM GMT      Jade     Muswell Hill      1-2 hrs
# 8   2022/11/18 2:04:15 PM GMT  Ning Wei       White city       3-4hrs
#
#   Use_App_Travel   Rate_App     Type_Transport UsePublicTransport  \
# 0            Yes       Good   All of the above                Yes
# 1            Yes       Good   All of the above                Yes
# 2            Yes  Excellent                Bus                Yes
# 3            Yes       Good                Bus                Yes
# 4            Yes       Fair                Bus                Yes
# 5             No       Good            Bicycle                Yes
# 6            Yes       Good  None of the above                Yes
# 7            Yes       Fair                Bus                Yes
# 8            Yes       Good   All of the above                Yes
#
#                                    Travel_challenges Variation_mobile_apps  \
# 0                            Catch the train on time                    No
# 1  Dealing with the crowds during rush hour and s...                   Yes
# 2    Bus is so busy it doesn't allow anyone to go in                   Yes
# 3                                               Rain                   Yes
# 4                                            traffic                    No
# 5                                              Rain!                   Yes
# 6                                                NaN                   Yes
# 7                                    Busy and delays                   Yes
# 8                                           Not sure                    No
#
#   Total_Apps_Used                                      Name_of_Apps  \
# 0             0-3                                        Google map
# 1             0-3  Citymapper, Google maps or Apple Maps if on foot
# 2             0-3                             Citimapper and Google
# 3             0-3                      Google Maps, Citymapper, TFL
# 4             0-3                                       google maps
# 5             0-3                              Google Maps, Transit
# 6             0-3                                       City Mapper
# 7             0-3               Citymapper, Apple maps, google maps
# 8             0-3                           Google map, City mapper
#
#   Satisfactory_outcome                                     Changes_needed
# 0                  Yes                                       Combining AR
# 1                  Yes  Important to note step free access, perhaps al...
# 2                  Yes  Telling you if the bus that is coming is full ...
# 3                  Yes                                                NaN
# 4                  Yes  You should have the option to filter your rout...
# 5                   No  It's dangerous to use apps while biking, how c...
# 6                  Yes  providing routes that are more suitable for pe...
# 7                  Yes  Providing the safest routes (not just the fast...
# 8                  Yes       They need to provide how safe the areas are.

# %%
Way['Name'].head()
# Out:
# 0      NaN
# 1      NaN
# 2    Rocio
# 3     Jana
# 4    Tilly
# Name: Name, dtype: object

# %%
Way.columns
# Out:
# Index(['Timestamp', 'Name', 'Area_Residence', 'Travel_Time', 'Use_App_Travel',
#        'Rate_App', 'Type_Transport', 'UsePublicTransport', 'Travel_challenges',
#        'Variation_mobile_apps', 'Total_Apps_Used', 'Name_of_Apps',
#        'Satisfactory_outcome', 'Changes_needed'],
#       dtype='object')

# %%
Way[['Name', 'Area_Residence', 'Travel_Time','Variation_mobile_apps','Name_of_Apps']]
# Out:
#        Name   Area_Residence  Travel_Time Variation_mobile_apps  \
# 0       NaN  Elephant&Castle  5 - 30 mins                    No
# 1       NaN          Chelsea       30-1hr                   Yes
# 2     Rocio           London  5 - 30 mins                   Yes
# 3      Jana        Battersea       30-1hr                   Yes
# 4     Tilly     Muswell Hill       30-1hr                    No
# 5       kat        Islington  5 - 30 mins                   Yes
# 6      Dara            Essex      1-2 hrs                   Yes
# 7      Jade     Muswell Hill      1-2 hrs                   Yes
# 8  Ning Wei       White city       3-4hrs                    No
#
#                                        Name_of_Apps
# 0                                        Google map
# 1  Citymapper, Google maps or Apple Maps if on foot
# 2                             Citimapper and Google
# 3                      Google Maps, Citymapper, TFL
# 4                                       google maps
# 5                              Google Maps, Transit
# 6                                       City Mapper
# 7               Citymapper, Apple maps, google maps
# 8                           Google map, City mapper

# %%
total =Way.isnull().sum().sort_values(ascending=False)
percent = (Way.isnull().sum()/Way.isnull().count()).sort_values(ascending=False)
missing = pd.concat([total, percent], axis=1, keys=[ 'Area_Residence', 'Travel_Time'])
missing.head()
# Out:
#                    Area_Residence  Travel_Time
# Name                            2     0.222222
# Travel_challenges               1     0.111111
# Changes_needed                  1     0.111111
# Timestamp                       0     0.000000
# Area_Residence                  0     0.000000

# %%
# replacing in word Rain! with Rain in Travel_challenges column
Way.replace('Rain!','Rain')
# Out:
#                     Timestamp      Name   Area_Residence  Travel_Time  \
# 0   2022/11/16 8:02:00 PM GMT       NaN  Elephant&Castle  5 - 30 mins
# 1   2022/11/16 8:12:46 PM GMT       NaN          Chelsea       30-1hr
# 2   2022/11/16 9:57:49 PM GMT     Rocio           London  5 - 30 mins
# 3   2022/11/17 9:54:48 AM GMT      Jana        Battersea       30-1hr
# 4   2022/11/17 9:55:01 AM GMT     Tilly     Muswell Hill       30-1hr
# 5   2022/11/17 3:03:59 PM GMT       kat        Islington  5 - 30 mins
# 6  2022/11/18 12:23:08 PM GMT      Dara            Essex      1-2 hrs
# 7   2022/11/18 1:19:35 PM GMT      Jade     Muswell Hill      1-2 hrs
# 8   2022/11/18 2:04:15 PM GMT  Ning Wei       White city       3-4hrs
#
#   Use_App_Travel   Rate_App     Type_Transport UsePublicTransport  \
# 0            Yes       Good   All of the above                Yes
# 1            Yes       Good   All of the above                Yes
# 2            Yes  Excellent                Bus                Yes
# 3            Yes       Good                Bus                Yes
# 4            Yes       Fair                Bus                Yes
# 5             No       Good            Bicycle                Yes
# 6            Yes       Good  None of the above                Yes
# 7            Yes       Fair                Bus                Yes
# 8            Yes       Good   All of the above                Yes
#
#                                    Travel_challenges Variation_mobile_apps  \
# 0                            Catch the train on time                    No
# 1  Dealing with the crowds during rush hour and s...                   Yes
# 2    Bus is so busy it doesn't allow anyone to go in                   Yes
# 3                                               Rain                   Yes
# 4                                            traffic                    No
# 5                                               Rain                   Yes
# 6                                                NaN                   Yes
# 7                                    Busy and delays                   Yes
# 8                                           Not sure                    No
#
#   Total_Apps_Used                                      Name_of_Apps  \
# 0             0-3                                        Google map
# 1             0-3  Citymapper, Google maps or Apple Maps if on foot
# 2             0-3                             Citimapper and Google
# 3             0-3                      Google Maps, Citymapper, TFL
# 4             0-3                                       google maps
# 5             0-3                              Google Maps, Transit
# 6             0-3                                       City Mapper
# 7             0-3               Citymapper, Apple maps, google maps
# 8             0-3                           Google map, City mapper
#
#   Satisfactory_outcome                                     Changes_needed
# 0                  Yes                                       Combining AR
# 1                  Yes  Important to note step free access, perhaps al...
# 2                  Yes  Telling you if the bus that is coming is full ...
# 3                  Yes                                                NaN
# 4                  Yes  You should have the option to filter your rout...
# 5                   No  It's dangerous to use apps while biking, how c...
# 6                  Yes  providing routes that are more suitable for pe...
# 7                  Yes  Providing the safest routes (not just the fast...
# 8                  Yes       They need to provide how safe the areas are.

# %%
Way["Travel_challenges"].value_counts()
# Out:
# Catch the train on time                                  1
# Dealing with the crowds during rush hour and strikes!    1
# Bus is so busy it doesn't allow anyone to go in          1
# Rain                                                     1
# traffic                                                  1
# Rain!                                                    1
# Busy and delays                                          1
# Not sure                                                 1
# Name: Travel_challenges, dtype: int64

# %%
#getting the top living Area_Residence from the 9 participants top Muswell Hill freQ-  2
Way['Area_Residence'].describe()
# Out:
# count                9
# unique               8
# top       Muswell Hill
# freq                 2
# Name: Area_Residence, dtype: object

# %%
Way['Type_Transport'].value_counts()
# Out:
# Bus                  4
# All of the above     3
# Bicycle              1
# None of the above    1
# Name: Type_Transport, dtype: int64

# %%
Way['Variation_mobile_apps'].value_counts()
# Out:
# Yes    6
# No     3
# Name: Variation_mobile_apps, dtype: int64

# %%
Way['Travel_Time'].value_counts()
# Out:
# 5 - 30 mins    3
# 30-1hr         3
# 1-2 hrs        2
# 3-4hrs         1
# Name: Travel_Time, dtype: int64

# %%
#getting the number of people per area and found ot that muswell hill has the highest
Way['Area_Residence'].value_counts()
# Out:
# Muswell Hill       2
# Elephant&Castle    1
# Chelsea            1
# London             1
# Battersea          1
# Islington          1
# Essex              1
# White city         1
# Name: Area_Residence, dtype: int64

# %%
#names of the 
address_df= Way[Way['Area_Residence']=='Muswell Hill']
address_df.head()
# Out:
#                    Timestamp   Name Area_Residence Travel_Time Use_App_Travel  \
# 4  2022/11/17 9:55:01 AM GMT  Tilly   Muswell Hill      30-1hr            Yes
# 7  2022/11/18 1:19:35 PM GMT   Jade   Muswell Hill     1-2 hrs            Yes
#
#   Rate_App Type_Transport UsePublicTransport Travel_challenges  \
# 4     Fair            Bus                Yes           traffic
# 7     Fair            Bus                Yes   Busy and delays
#
#   Variation_mobile_apps Total_Apps_Used                         Name_of_Apps  \
# 4                    No             0-3                          google maps
# 7                   Yes             0-3  Citymapper, Apple maps, google maps
#
#   Satisfactory_outcome                                     Changes_needed
# 4                  Yes  You should have the option to filter your rout...
# 7                  Yes  Providing the safest routes (not just the fast...

# %%
address_df= Way[Way['Area_Residence']=='Muswell Hill']
address_df.head()
# Out:
#                    Timestamp   Name Area_Residence Travel_Time Use_App_Travel  \
# 4  2022/11/17 9:55:01 AM GMT  Tilly   Muswell Hill      30-1hr            Yes
# 7  2022/11/18 1:19:35 PM GMT   Jade   Muswell Hill     1-2 hrs            Yes
#
#   Rate_App Type_Transport UsePublicTransport Travel_challenges  \
# 4     Fair            Bus                Yes           traffic
# 7     Fair            Bus                Yes   Busy and delays
#
#   Variation_mobile_apps Total_Apps_Used                         Name_of_Apps  \
# 4                    No             0-3                          google maps
# 7                   Yes             0-3  Citymapper, Apple maps, google maps
#
#   Satisfactory_outcome                                     Changes_needed
# 4                  Yes  You should have the option to filter your rout...
# 7                  Yes  Providing the safest routes (not just the fast...

# %%
print(Way.shape)
# Out:
# (9, 14)

# %%
# getting missing values in data
Way.isnull().sum()
# Out:
# Timestamp                0
# Name                     2
# Area_Residence           0
# Travel_Time              0
# Use_App_Travel           0
# Rate_App                 0
# Type_Transport           0
# UsePublicTransport       0
# Travel_challenges        1
# Variation_mobile_apps    0
# Total_Apps_Used          0
# Name_of_Apps             0
# Satisfactory_outcome     0
# Changes_needed           1
# dtype: int64

# %%
Way.describe()
# Out:
#                         Timestamp   Name Area_Residence  Travel_Time  \
# count                           9      7              9            9
# unique                          9      7              8            4
# top     2022/11/16 8:02:00 PM GMT  Rocio   Muswell Hill  5 - 30 mins
# freq                            1      1              2            3
#
#        Use_App_Travel Rate_App Type_Transport UsePublicTransport  \
# count               9        9              9                  9
# unique              2        3              4                  1
# top               Yes     Good            Bus                Yes
# freq                8        6              4                  9
#
#               Travel_challenges Variation_mobile_apps Total_Apps_Used  \
# count                         8                     9               9
# unique                        8                     2               1
# top     Catch the train on time                   Yes             0-3
# freq                          1                     6               9
#
#        Name_of_Apps Satisfactory_outcome Changes_needed
# count             9                    9              8
# unique            9                    2              8
# top      Google map                  Yes   Combining AR
# freq              1                    8              1

# %%
# Names od Mobile apps Used Name_of_Apps
Way['Name_of_Apps'].unique()
# Out:
# array(['Google map', 'Citymapper, Google maps or Apple Maps if on foot',
#        'Citimapper and Google', 'Google Maps, Citymapper, TFL',
#        'google maps', 'Google Maps, Transit', 'City Mapper',
#        'Citymapper, Apple maps, google maps', 'Google map, City mapper'],
#       dtype=object)

# %%
#relating scateplots with the variables
Way['Area_Residence']
# Out:
# 0    Elephant&Castle
# 1            Chelsea
# 2             London
# 3          Battersea
# 4       Muswell Hill
# 5          Islington
# 6              Essex
# 7       Muswell Hill
# 8         White city
# Name: Area_Residence, dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# using the crossbar chart is a tabulation of two diffrent category variables to getim travel times from particibats
pd.crosstab(Way['Name'], Way['Travel_Time'])
# Out:
# Travel_Time  1-2 hrs  3-4hrs  30-1hr  5 - 30 mins
# Name
# Dara               1       0       0            0
# Jade               1       0       0            0
# Jana               0       0       1            0
# Ning Wei           0       1       0            0
# Rocio              0       0       0            1
# Tilly              0       0       1            0
# kat                0       0       0            1

# %%
# print out all the Types of transport 
Way.Type_Transport.value_counts()
# Out:
# Bus                  4
# All of the above     3
# Bicycle              1
# None of the above    1
# Name: Type_Transport, dtype: int64

# %%
# print out all the unique values from this Series (ie column)
Way.Name.unique()
# Out:
# array([nan, 'Rocio', 'Jana', 'Tilly', 'kat', 'Dara', 'Jade', 'Ning Wei'],
#       dtype=object)

# %%
Way.Travel_challenges.value_counts()
# Out:
# Catch the train on time                                  1
# Dealing with the crowds during rush hour and strikes!    1
# Bus is so busy it doesn't allow anyone to go in          1
# Rain                                                     1
# traffic                                                  1
# Rain!                                                    1
# Busy and delays                                          1
# Not sure                                                 1
# Name: Travel_challenges, dtype: int64

# %%
Way = pd.DataFrame(Way)
Way.set_index(["Name", "Area_Residence"]).unstack("Area_Residence").plot(kind="bar", rot=0)

plt.show()

# %%
#tried several methods and can't seem to get a decent graph.
